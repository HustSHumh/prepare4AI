# %%
# 10月15号预测功率最大值汇总
{
    "广东":4387.11,
    "阳江":538.08,
    "湛江":797.85,
    "广西":3533.93,
    "南宁":640.34,
    "钦州":517.22,
    "贵州":3115.15,
    "六盘水":208.61,
    "兴义":716.36,
    "海南":791.7,
    "儋州":262.63,
    "海口":219.97,
    "云南":5008.77,
    "楚雄":942.73,
    "大理":1054.22,
}

# %%
# 10月16号预测功率最大值汇总
{
    "广东":4689.58,
    "阳江":565.6,
    "湛江":909.36,
    "广西":3735.7,
    "南宁":641.32,
    "钦州":586.74,
    "贵州":4264.66,
    "六盘水":288.32,
    "兴义":945.84,
    "海南":716.53,
    "儋州":254.26,
    "海口":165.41,
    "云南":5662.18,
    "楚雄":1079.03,
    "大理":1083.27,
}

# %%
# 10月17号预测功率最大值汇总
{
    "广东":3723.92,
    "阳江":338.93,
    "湛江":561.48,
    "广西":1234.15,
    "南宁":55.4,
    "钦州":106.15,
    "贵州":4096.38,
    "六盘水":244.79,
    "兴义":1058.37,
    "海南":198.2,
    "儋州":72.22,
    "海口":82.1,
    "云南":,5660.96
    "楚雄":1088.16,
    "大理":912.66,
}

# %%
# 10月19号预测功率最大值汇总
{
    "云南":6317.51,
    "大理":964.92,
    "楚雄":1224.41,
    "广东":1667.15,
    "湛江":258.68,
    "阳江":143.37,
    "广西":1230.45,
    "南宁":207.83,
    "钦州":131.69,
    "海南":814.46,
    "儋州":187.03,
    "海口":257.78,
    "贵州":2932.65,
    "六盘水":259.87,
    "兴义":868.83,
}

# %%
# 10月18号预测功率最大值汇总
{
    "云南":6366.21,
    "大理":971.79,
    "楚雄":1181.63,
    "广东":2213.48,
    "湛江":373.12,
    "阳江":176.42,
    "广西":2766.93,
    "南宁":520.24,
    "钦州":263.24,
    "海南":593.63,
    "儋州":171.44,
    "海口":165.98,
    "贵州":4769.25,
    "六盘水":406.03,
    "兴义":1106.74,
}
